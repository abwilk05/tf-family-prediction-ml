# %%
import matplotlib.pyplot as plt
import numpy as np

acc_DL = [0.7971698113207547, 0.8915094339622641, 0.8490566037735849, 0.8009478672985783, 0.7962085308056872, 0.8483412322274881, 0.8293838862559242, 0.7867298578199052, 0.8009478672985783, 0.8009478672985783]
acc_DL_consensus = [0.7216981132075472, 0.839622641509434, 0.7688679245283019, 0.7251184834123223, 0.7203791469194313, 0.7535545023696683, 0.7488151658767772, 0.7535545023696683, 0.7014218009478673, 0.7725118483412322]
acc_KNN = 0.8400378608613346
acc_KNN_consensus = 0.7903454803596782

heights = [np.mean(acc_DL), np.mean(acc_DL_consensus), acc_KNN, acc_KNN_consensus]
x_pos = [1,2,3,4]
yerrs = [np.std(acc_DL), np.std(acc_DL_consensus), 0, 0]
colors = ['#e41a1c','#e41a1c','#377eb8','#377eb8']

fig, ax = plt.subplots(figsize=(8, 9))

bars = ax.bar(x_pos, heights, color=colors, yerr=yerrs, capsize=2)
labels = ['PWMs','Consensus Sequences']*2
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(labels, rotation=45, ha='right', rotation_mode='anchor', fontsize=10)
ax.set_ylim(0.6,0.9)

plt.tight_layout()

plt.show()
